# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
m = 1000; d = 10
x = np.random.normal(2,10,(m,d))
x_t = (x-x.mean())/x.std()
plt.hist(x_t,label="std")
plt.hist(x,histtype='step',label="non-std")
plt.legend()
plt.show()
