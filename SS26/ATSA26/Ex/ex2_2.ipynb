# %%
options(repr.plot.width = 7, repr.plot.height = 7, repr.plot.res = 200)
par(mfrow=c(3,1),lwd = 2,font.axis = 1.2, font.lab = 1.2, font.main = 1.2,
    cex.axis = 1.2, cex.lab = 1.2, cex.main = 1.2)
plot(decompose(x = co2,type="additive"))
# Out:
# plot without title
