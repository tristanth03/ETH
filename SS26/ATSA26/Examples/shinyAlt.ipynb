# %%
import numpy as np

def f(mu,sigma):
    return np.random.normal(mu,sigma,size=(1000,)),np.random.normal(mu,sigma,size=(1000,))

# %%
# my test case
import matplotlib.pyplot as plt
plt.subplot(2,2,1)
_,y = f(1,2)
plt.plot(y)
plt.subplot(2,2,2)
plt.hist(y)
plt.show()

# %% [markdown]
# This is a beauty
# $$f = \mathcal{b} \int_a du$$
