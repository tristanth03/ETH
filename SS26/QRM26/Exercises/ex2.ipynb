# %%
phi <- function(x)
{1/sqrt(2*pi) * exp(-(x**2)/2)}

# %%
11/15+sqrt(593.9)*phi(qnorm(0.8))/0.2
# Out:
# [1] 34.84678

# %%
(11/15+5*sqrt(593.9)*(phi(qnorm(0.8))-phi(qnorm(1))))
# Out:
# [1] 34.84678

# %%
qbinom(0.5,size=1,prob=0.5)+qbinom(0.5,size=1,prob=0.5)
# Out:
# [1] 0

# %%
# Out:
# [1] 0.5
